# %% [markdown]
# <a href="https://colab.research.google.com/github/kundrapuharsha/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of skills needed in the AI field, from foundational to strategic. Here are 4 short bullet points explaining it:
#
# *   **Data & ML Engineering:** Foundational skills in data management, processing, and building/training core machine learning models.
# *   **Domain Expertise & Application:** Applying AI solutions to solve real-world problems within specific industries or contexts.
# *   **AI Research & Innovation:** Developing novel algorithms, techniques, and advancing the state-of-the-art in AI.
# *   **AI Strategy & Leadership:** Defining AI vision, ethical guidelines, ensuring business value, and leading AI initiatives.
